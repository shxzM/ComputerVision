# %% [markdown]
# <a href="https://colab.research.google.com/github/shxzM/ComputerVision/blob/main/yolov11_exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %pip install ultralytics
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 33.1/112.6 GB disk)

# %%
# !unzip -q ../content/yolo_thermal.zip -d ../content

# %%
# !yolo train model=yolo11m.pt data=/content/plants.yaml epochs=150 imgsz=256
# Out:
# ...
# 100% 38.8M/38.8M [00:00<00:00, 46.7MB/s]
# Ultralytics 8.3.74 🚀 Python-3.11.11 torch-2.5.1+cu124 CUDA:0 (Tesla T4, 15095MiB)
# ...
